# %% [markdown]
# # Readabilty and semantic cohesion between MOOCs sections - Part III
#
#
# ## Introduction
#
# We explore whether we can infer vector representations for course sections and capture semantics similarities between them using doc2vec model.  This might be useful to identify how smooth is the content flow of the course.
#
# ### Importing libriaries and gensim model

# %%
import gensim
from gensim.models import Doc2Vec

model0 = Doc2Vec.load("model0") # loading trained doc2vec model
print (len(model0.docvecs))
# Out:
# 285

# %% [markdown]
# ### Defining text preprocessing function
#
# The data was preprocessed so that all the punctuation,  numerical symbols and stop words were removed from the text.

# %%
import os,re,json
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize,wordpunct_tokenize
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords

def text_preprocess(raw, code):
    
    hiragana_full = r'[ぁ-ゟ]'
    katakana_full = r'[゠-ヿ]'
    kanji = r'[㐀-䶵一-鿋豈-頻]'
    
    list_of_words = []
    raw = re.sub(r"https?:\/\/(www\.)?[-a-zA-Z0-9@:%._\+~#=]{2,256}\.[a-z]{2,6}\b([-a-zA-Z0-9@:%_\+.~#?&//=]*)",'', raw)
    raw = re.sub("&#39;", "'", raw)
    
    #remove japanese chars
    raw = re.sub(hiragana_full,'', raw)
    raw = re.sub(katakana_full,'', raw)
    raw = re.sub(kanji,'', raw)
    
    token = wordpunct_tokenize(raw)
    stopword_obj = stopwords.words('english')
    list_of_words=[]
    steming_type = PorterStemmer()
    for i in token:
        processed_tmp = i.lower()
        
        if len(processed_tmp) == 1:
            continue
        
        if code[0] == '1':
            if not processed_tmp.isalpha():
                continue
        else:
            if not processed_tmp.isalnum():
                continue

        if code[1] == '1':
            if processed_tmp in stopword_obj:
                continue
     
        if code[2] == '1':
            processed_tmp = steming_type.stem(processed_tmp)
        
        list_of_words.append(processed_tmp)

    return list_of_words

# %% [markdown]
# Using similar document embedding approach as before, we now learn vectors for individual MOOC sections.
# Since section consists of multiple components, we combined the data from all the components.

# %%
from os import listdir
import json
from os.path import isfile, join

# extract and store the content of the sections in a dictionary 
def get_course_sections(course_path):
    
    section_to_content =  defaultdict(list)
    sections = next(os.walk(course_path))[1]
    
    for comp_type in selected_components:
        if os.path.exists(os.path.join(course_path,comp_type)):
            with open(os.path.join(course_path,comp_type),'r',encoding='utf-8') as file:
                json_data = json.loads(file.read())      
                for sec in sections:
                    for main_key, main_value in json_data.items():
                        if (main_value['section']==sec):
                            if comp_type == 'all_videocomp.json' and main_value['transcript_en']!='': 
                                section_to_content[sec].append(main_value['transcript_en'])
                            if comp_type == 'all_textcomp.json' and main_value['content']!='': 
                                section_to_content[sec].append(main_value['content'])  
        else:
            continue
    return section_to_content

# %% [markdown]
# Our hypothesis is that if the model learns vector representations of the individual sections well, then we should be able to see higher similarity scores between two neighboring section vectors, rather than between two sections far apart in the course.
#
# To  verify  this  hypothesis,  we  define  two  measures:
# * Pairwise comparison score
# * Linear comparison score
#
# The  first  measure, pairwise comparison score measures how similar are any two sections in the course. Pairwisecomparison score (pc-score)compares each section to every other section in the given MOOC,
# resulting in (N choose 2)comparison pairs.

# %%
from sklearn.metrics.pairwise import cosine_similarity

def compute_parwise_similarity(section_to_vector):
        
    total_sum = 0
    keys = sorted(section_to_vector.keys())
    
    for i in range(0, len(keys)): 
        for j in range(i+1, len(keys)):
            vector_i = section_to_vector[keys[i]].reshape(1, -1)
            vector_j = section_to_vector[keys[j]].reshape(1, -1)
            cos_sim = cosine_similarity(vector_i, vector_j)
            total_sum += cos_sim
    if(len(section_to_vector)>1):        
        total_section_sim = total_sum*2/((len(section_to_vector))**2)
    else:
        total_section_sim = total_sum
        
    print ("Pairwise_similarity: {0} ".format(total_section_sim))
    
    return total_section_sim

# %% [markdown]
# The second measure we defined is section’s linear similarity score. Linear comparison score (lc-sore) compares sections sequentially:  first section to the second, second to the third, and so on. If themodel is trained well, it should capture the semantic similarity of consequent sections, and linear similarity should be higher than pairwise similarity.

# %%
from sklearn.metrics.pairwise import cosine_similarity

def compute_linear_similarity(section_to_vector):
    
    cur_ind = 0
    total_sum_linear=0
    keys = sorted(section_to_vector.keys())
    linear_similarities = []
    
    for next_ind in range(1,len(keys)):
        vector_i = section_to_vector[keys[cur_ind]].reshape(1, -1)
        vector_j = section_to_vector[keys[next_ind]].reshape(1, -1)
        cos_sim = cosine_similarity(vector_i,vector_j)
        linear_similarities.append(cos_sim)
        total_sum_linear += cos_sim
        cur_ind += 1
        
    if(len(section_to_vector)>1):        
        total_section_sim_linear = total_sum_linear/(len(section_to_vector)-1)
    else:
        total_section_sim_linear = total_sum_linear
        
    print ("Linear_similarity: {0} ".format(total_section_sim_linear))
    
    return total_sum_linear/(len(keys)-1), linear_similarities

# %% [markdown]
# ## Compute section vectors for the entire dataset

# %% [markdown]
# Next, we calculate  lc-score and pc-score for all the courses in our dataset. We identified the overall trend that lc-scores are higher than pc-scores for majority of the MOOCs.

# %%
from collections import defaultdict

rootDir='/home/zarina/Documents/OEDO/web-crawler/HTMLs/'
selected_components=['all_textcomp.json', 'all_videocomp.json']
course_dir = [tmp for tmp in os.listdir(rootDir)]
readabilities=[]
case_count=0

pairwise_sim_points = []
linear_sim_points = []
course_names = []

for course in course_dir:
    
    course_names.append(course)
    course_path=rootDir+course #/rootDir/course_name
    print (course_path)
    
    section_to_content =  defaultdict(list)
    section_to_vector =  defaultdict(list)
    
    section_to_content = get_course_sections(course_path)
    
    section_to_vector =  defaultdict(list)
    for key, value in section_to_content.items():
        #combine list
        section_txt=''.join(str(e) for e in value)
        #clean text '110' - alphabetic, numeric
        clean_txt=text_preprocess(section_txt, '110')
        #inferred_embedding
        inferred_embedding = model0.infer_vector(clean_txt)
        #store embedding in map
        section_to_vector[key]=inferred_embedding
    
    pairwise_section_sim = compute_parwise_similarity(section_to_vector)
    pairwise_sim_points.append(pairwise_section_sim)
    
    linear_section_sim, _ = compute_linear_similarity(section_to_vector)
    linear_sim_points.append(linear_section_sim)
    
    if (linear_section_sim < pairwise_section_sim):
        print ("UNUSUAL CASE")
        case_count+=1
    
    #course_readability = compute_average_readability(section_to_content)
    #readabilities.append(course_readability)
    
print ("UNUSUAL CASE COUNT", case_count)
# Out:
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Global_Social_Change
# Pairwise_similarity: [[0.4598183]]
# Linear_similarity: [[0.5645105]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Compliance_in_Office_365-_Data_Governance
# Pairwise_similarity: [[0.36815226]]
# Linear_similarity: [[0.47528377]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/DNA_Sequences-_Alignments_and_Analysis
# Pairwise_similarity: [[0.4475976]]
# Linear_similarity: [[0.53283197]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Cyberwar_Surveillance_and_Security
# Pairwise_similarity: [[0.5030408]]
# Linear_similarity: [[0.6166206]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Luxury_Management
# Pairwise_similarity: [[0.3712026]]
# Linear_similarity: [[0.39380205]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Solar_Energy-_Photovoltaic_PV_Systems
# Pairwise_similarity: [[0.4258001]]
# Linear_similarity: [[0.60358715]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Supply_Chain_Management-_A_Decision-Making_Framework
# Pairwise_similarity: [[0.46904308]]
# Linear_similarity: [[0.5728465]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Engagement_in_a_Time_of_Polarization
# Pairwise_similarity: [[0.4923639]]
# Linear_similarity: [[0.650669]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Software_Testing_Management
# Pairwise_similarity: [[0.621798]]
# Linear_similarity: [[0.7718629]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Socially-Responsible_Real_Estate_Development-_Learning_to_Use_Impact_Assessment_Tools_Effectively
# Pairwise_similarity: [[0.5169725]]
# Linear_similarity: [[0.6569764]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Introduction_to_Philosophy-_God_Knowledge_and_Consciousness
# Pairwise_similarity: [[0.32281002]]
# Linear_similarity: [[0.40877613]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Science_in_Art-_The_Chemistry_of_Art_Materials_and_Conservation
# Pairwise_similarity: [[0.40894598]]
# Linear_similarity: [[0.55799705]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Science__Cooking-_From_Haute_Cuisine_to_Soft_Matter_Science_part_1
# Pairwise_similarity: [[0.5614656]]
# Linear_similarity: [[0.67844164]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Spirituality_and_Sensuality-_Sacred_Objects_in_Religious_Life
# Pairwise_similarity: [[0.34790975]]
# Linear_similarity: [[0.49651304]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Microsoft_SharePoint_Online_for_Site_Administrators
# Pairwise_similarity: [[0.4035492]]
# Linear_similarity: [[0.5455514]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Big_Bang_and_the_Origin_of_Chemical_Elements
# Pairwise_similarity: [[0.4807909]]
# Linear_similarity: [[0.6952366]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Democracy_and_Development-_Perspectives_from_Africa
# Pairwise_similarity: [[0.43317997]]
# Linear_similarity: [[0.55562]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Monasteries_Schools_and_Notaries_Part_1-_Reading_the_Late_Medieval_Marseille_Archive
# Pairwise_similarity: [[0.4898232]]
# Linear_similarity: [[0.6440161]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/The_Conscious_Mind-_A_Philosophical_Road_Trip
# Pairwise_similarity: [[0.41944966]]
# Linear_similarity: [[0.5186265]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Computation_Structures_1-_Digital_Circuits
# Pairwise_similarity: [[0.30486295]]
# Linear_similarity: [[0.41472548]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Sustainability_Resilience_and_Society
# Pairwise_similarity: [[0.45465347]]
# Linear_similarity: [[0.594555]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Provisioning_Office_365_Services
# Pairwise_similarity: [[0.39571473]]
# Linear_similarity: [[0.53156614]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Compliance_in_Office_365-_eDiscovery
# Pairwise_similarity: [[0.40208784]]
# Linear_similarity: [[0.5462717]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Python_for_Data_Science
# Pairwise_similarity: [[0.40353143]]
# Linear_similarity: [[0.4690922]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Human_Rights-_The_Right_to_Freedom_of_Expression
# Pairwise_similarity: [[0.5109271]]
# Linear_similarity: [[0.65807927]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Video_Game_Asset_Creation_and_Process
# Pairwise_similarity: [[0.3667702]]
# Linear_similarity: [[0.48588815]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Computational_Probability_and_Inference
# Pairwise_similarity: [[0.3757921]]
# Linear_similarity: [[0.5199706]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Innovation_Leadership
# Pairwise_similarity: [[0.5896509]]
# Linear_similarity: [[0.7136147]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Statistics_for_Business_-_II
# Pairwise_similarity: [[0.44974563]]
# Linear_similarity: [[0.504402]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Nanophotonic_Modeling
# Pairwise_similarity: [[0.4959813]]
# Linear_similarity: [[0.7130342]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Music_For_Wellness
# Pairwise_similarity: [[0.53052247]]
# Linear_similarity: [[0.66820467]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Global_Inequality
# Pairwise_similarity: [[0.41592094]]
# Linear_similarity: [[0.5428732]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Gameplay_Programming_for_Video_Game_Designers
# Pairwise_similarity: [[0.46478266]]
# Linear_similarity: [[0.6454056]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Analytics_in_Python
# Pairwise_similarity: [[0.41987437]]
# Linear_similarity: [[0.5269228]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Lean_Production
# Pairwise_similarity: [[0.49374175]]
# Linear_similarity: [[0.5842008]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Retail_Fundamentals
# Pairwise_similarity: [[0.44087827]]
# Linear_similarity: [[0.60796183]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Microsoft_SharePoint_2016-_Infrastructure
# Pairwise_similarity: [[0.37741205]]
# Linear_similarity: [[0.5240771]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Measuring_Health_Outcomes_in_Field_Surveys
# Pairwise_similarity: [[0.41677815]]
# Linear_similarity: [[0.54523784]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Results-Based_Project_Management-_Monitoring_and_Evaluation
# Pairwise_similarity: [[0.5165659]]
# Linear_similarity: [[0.6133393]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Magnetic_Materials_and_Devices
# Pairwise_similarity: [[0.37321663]]
# Linear_similarity: [[0.54871655]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Introduction_to_the_Internet_of_Things_IoT
# Pairwise_similarity: [[0.37360042]]
# Linear_similarity: [[0.4654449]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Structuring_Successful_Business_Deals
# Pairwise_similarity: [[0.51364577]]
# Linear_similarity: [[0.64406013]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/The_Beauty_and_Joy_of_Computing_-_AP_CS_Principles_Part_1
# Pairwise_similarity: [[0.337307]]
# Linear_similarity: [[0.43091586]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Faith_and_Finance
# Pairwise_similarity: [[0.4691032]]
# Linear_similarity: [[0.6079775]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/How_Stuff_Moves_Part_2-_Angular_Motion
# Pairwise_similarity: [[0.5236522]]
# Linear_similarity: [[0.70799536]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Mandarin_Chinese_for_Business
# Pairwise_similarity: [[0.6385004]]
# Linear_similarity: [[0.81735486]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/The_Divine_Comedy-_Dantes_Journey_to_Freedom_Part_3_Paradiso
# Pairwise_similarity: [[0.33441246]]
# Linear_similarity: [[0.3801782]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/English_for_Doing_Business_in_Asia_-_Writing
# Pairwise_similarity: [[0.4240709]]
# Linear_similarity: [[0.48449275]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Office_365-_SharePoint_Online_Administrator
# Pairwise_similarity: [[0.3935657]]
# Linear_similarity: [[0.54420143]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Shakespeare-_On_the_Page_and_in_Performance
# Pairwise_similarity: [[0.5642993]]
# Linear_similarity: [[0.6808514]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Calculus_1A-_Differentiation
# Pairwise_similarity: [[0.5089665]]
# Linear_similarity: [[0.6349706]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Hong_Kong_Cinema_Through_a_Global_Lens
# Pairwise_similarity: [[0.5161221]]
# Linear_similarity: [[0.5985965]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Transfer_Functions_and_the_Laplace_Transform
# Pairwise_similarity: [[0.4680661]]
# Linear_similarity: [[0.51634926]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Information_Systems_and_Computer_Applications_Part_5-_Social_Implications
# Pairwise_similarity: [[0.3760592]]
# Linear_similarity: [[0.5626652]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Ignorance
# Pairwise_similarity: [[0.58533275]]
# Linear_similarity: [[0.69740665]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Introduction_to_Corporate_Finance
# Pairwise_similarity: [[0.34997976]]
# Linear_similarity: [[0.50919604]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Innovation_Generation-_How_to_Be_Creative
# Pairwise_similarity: [[0.47024345]]
# Linear_similarity: [[0.583652]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/The_Search_for_Vernacular_Architecture_of_Asia_Part_1
# Pairwise_similarity: [[0.43382293]]
# Linear_similarity: [[0.59372026]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Foreign_Exchange_Markets-_Instruments_Risks_and_Derivatives
# Pairwise_similarity: [[0.4178791]]
# Linear_similarity: [[0.52053744]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Making_and_Meaning_in_the_Medieval_Manuscript
# Pairwise_similarity: [[0.51608074]]
# Linear_similarity: [[0.62801045]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Developing_Windows_10_Universal_Apps__Part_3
# Pairwise_similarity: [[0.35298052]]
# Linear_similarity: [[0.50009644]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Make_Your_Own_App
# Pairwise_similarity: [[0.3902231]]
# Linear_similarity: [[0.34038457]]
# UNUSUAL CASE
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Vocal_Recording_Technology
# Pairwise_similarity: [[0.4925091]]
# Linear_similarity: [[0.61389154]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Basic_Mandarin_Chinese__Level_3
# Pairwise_similarity: [[0.48447555]]
# Linear_similarity: [[0.6647113]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Networks_Crowds_and_Markets
# Pairwise_similarity: [[0.3704893]]
# Linear_similarity: [[0.47906122]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/The_Great_War_and_Modern_Philosophy
# Pairwise_similarity: [[0.5137221]]
# Linear_similarity: [[0.6799283]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Proteins-_Alignment_Analysis_and_Structure
# Pairwise_similarity: [[0.4491341]]
# Linear_similarity: [[0.5218808]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Humanity_and_Nature_in_Chinese_Thought
# Pairwise_similarity: [[0.45197597]]
# Linear_similarity: [[0.5638662]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Advanced_Software_Construction_in_Java
# Pairwise_similarity: [[0.42721847]]
# Linear_similarity: [[0.39598566]]
# UNUSUAL CASE
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Democratic_to_Authoritarian_Rule
# Pairwise_similarity: [[0.38551039]]
# Linear_similarity: [[0.47083393]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Microsoft_Professional_Orientation_-_Front_End_Web_Development
# Pairwise_similarity: [[0.29485792]]
# Linear_similarity: [[0.4883005]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/MyCS-_Computer_Science_for_Beginners
# Pairwise_similarity: [[0.29076788]]
# Linear_similarity: [[0.3999636]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/The_Science_of_Parenting
# Pairwise_similarity: [[0.48487526]]
# Linear_similarity: [[0.62520903]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/China_Humanities-_The_Individual_in_Chinese_Culture
# Pairwise_similarity: [[0.48577034]]
# Linear_similarity: [[0.5673591]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Data_Visualization_for_All
# Pairwise_similarity: [[0.5455524]]
# Linear_similarity: [[0.66517586]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/AP_English_Literature__Composition__Part_2-_Poems
# Pairwise_similarity: [[0.46874487]]
# Linear_similarity: [[0.596175]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Data_Analytics_in_Health__From_Basics_to_Business
# Pairwise_similarity: [[0.3703774]]
# Linear_similarity: [[0.54666495]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/On-Ramp_to_AP_Calculus
# Pairwise_similarity: [[0.35355493]]
# Linear_similarity: [[0.46623912]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Electronic_Materials_and_Devices
# Pairwise_similarity: [[0.44104186]]
# Linear_similarity: [[0.633793]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Writing_Case_Studies-_Science_of_Delivery
# Pairwise_similarity: [[0.4791101]]
# Linear_similarity: [[0.5864418]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Hospitality_and_Tourism_in_China-_A_Global_Perspective
# Pairwise_similarity: [[0.46463513]]
# Linear_similarity: [[0.5474954]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Tangible_Things
# Pairwise_similarity: [[0.34457773]]
# Linear_similarity: [[0.44630444]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Managing_Building_Adaptation-_A_Sustainable_Approach
# Pairwise_similarity: [[0.4906515]]
# Linear_similarity: [[0.5817377]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Print_and_Manuscript_in_Western_Europe_Asia_and_the_Middle_East_1450-1650
# Pairwise_similarity: [[0.47474214]]
# Linear_similarity: [[0.60654116]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Microsoft_SharePoint_2016-_Search_and_Content_Management
# Pairwise_similarity: [[0.31931445]]
# Linear_similarity: [[0.48336205]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Minecraft_Coding_and_Teaching
# Pairwise_similarity: [[0.4341945]]
# Linear_similarity: [[0.62469715]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/eHealth__Opportunities_and_Challenges
# Pairwise_similarity: [[0.36308005]]
# Linear_similarity: [[0.4091516]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Cement_Chemistry_and_Sustainable_Cementitious_Materials
# Pairwise_similarity: [[0.35755026]]
# Linear_similarity: [[0.43562815]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Robot_Mechanics_and_Control_Part_II
# Pairwise_similarity: [[0.39801487]]
# Linear_similarity: [[0.54859346]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Chinese_Thought-_Ancient_Wisdom_Meets_Modern_Science_-_Part_2
# Pairwise_similarity: [[0.35403392]]
# Linear_similarity: [[0.5167514]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/The_Divine_Comedy-_Dantes_Journey_to_Freedom_Part_2_Purgatorio
# Pairwise_similarity: [[0.3096442]]
# Linear_similarity: [[0.37016857]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/How_to_Write_an_Essay
# Pairwise_similarity: [[0.5070439]]
# Linear_similarity: [[0.6740539]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Just_Money-_Banking_as_if_Society_Mattered
# Pairwise_similarity: [[0.49848816]]
# Linear_similarity: [[0.55195874]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Symmetry_Structure_and_Tensor_Properties_of_Materials
# Pairwise_similarity: [[0.4933759]]
# Linear_similarity: [[0.57904375]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/DNA_and_Atoms-_The_Secret_of_Life
# Pairwise_similarity: [[0.44136196]]
# Linear_similarity: [[0.65246516]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Cybersecurity_Fundamentals
# Pairwise_similarity: [[0.37344003]]
# Linear_similarity: [[0.52437735]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Credit_Risk_Management
# Pairwise_similarity: [[0.43894538]]
# Linear_similarity: [[0.51767766]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Realtime_Bluetooth_Networks
# Pairwise_similarity: [[0.50630575]]
# Linear_similarity: [[0.6469967]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Atomic_and_Optical_Physics-_Quantum_States_and_Dynamics_of_Photons
# Pairwise_similarity: [[0.4847412]]
# Linear_similarity: [[0.5808319]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Robotics
# Pairwise_similarity: [[0.4144773]]
# Linear_similarity: [[0.5464813]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Strategic_Management
# Pairwise_similarity: [[0.3729273]]
# Linear_similarity: [[0.5011573]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Business_and_Its_Environment-_An_Overview_of_Business_and_the_Role_of_Finance
# Pairwise_similarity: [[0.3622843]]
# Linear_similarity: [[0.5201506]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Basic_Mandarin_Chinese_-_Level_2
# Pairwise_similarity: [[0.53741294]]
# Linear_similarity: [[0.6559678]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Human_Rights_and_Development_T3_2017
# Pairwise_similarity: [[0.49700192]]
# Linear_similarity: [[0.57645416]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Optical_Materials_and_Devices
# Pairwise_similarity: [[0.4346245]]
# Linear_similarity: [[0.6198057]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Computation_Structures_3-_Computer_Organization
# Pairwise_similarity: [[0.32115448]]
# Linear_similarity: [[0.41584954]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Digital_Networks_Essentials
# Pairwise_similarity: [[0.45015174]]
# Linear_similarity: [[0.5464226]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Leadership_for_Engineers
# Pairwise_similarity: [[0.42475402]]
# Linear_similarity: [[0.5612949]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/ChinaX_Part_1-_Political_and_Intellectual_Foundations-_From_the_Sage_Kings_to_Confucius_and_the_Legalists
# Pairwise_similarity: [[0.37487003]]
# Linear_similarity: [[0.4498566]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Fundamentals_of_Manufacturing_Processes
# Pairwise_similarity: [[0.4954486]]
# Linear_similarity: [[0.5622459]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Counseling_and_Psychotherapy_Theory
# Pairwise_similarity: [[0.5739467]]
# Linear_similarity: [[0.6721764]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Introduction_to_Accounting_-_1
# Pairwise_similarity: [[0.49043766]]
# Linear_similarity: [[0.6560521]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Data_Analysis-_Visualization_and_Dashboard_Design
# Pairwise_similarity: [[0.5345758]]
# Linear_similarity: [[0.6513221]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Design_and_Development_of_Educational_Technology
# Pairwise_similarity: [[0.56851864]]
# Linear_similarity: [[0.6856958]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Understanding_Wireless-_Technology_Economics_and_Policy
# Pairwise_similarity: [[0.35024157]]
# Linear_similarity: [[0.4256508]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/LAFF-On_Programming_for_Correctness
# Pairwise_similarity: [[0.4871725]]
# Linear_similarity: [[0.66613847]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Principles_of_Designing_for_Humans
# Pairwise_similarity: [[0.3578447]]
# Linear_similarity: [[0.5036281]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Computation_Structures_2-_Computer_Architecture
# Pairwise_similarity: [[0.33704314]]
# Linear_similarity: [[0.3953891]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/The_Writing_Process
# Pairwise_similarity: [[0.3974444]]
# Linear_similarity: [[0.6003062]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Sustainable_Energy-_Design_a_Renewable_Future
# Pairwise_similarity: [[0.50554675]]
# Linear_similarity: [[0.58015317]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/People_Management
# Pairwise_similarity: [[0.431573]]
# Linear_similarity: [[0.4662428]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Waves__Optics
# Pairwise_similarity: [[0.430514]]
# Linear_similarity: [[0.52049726]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Positive_Behavior_Support_for_Young_Children
# Pairwise_similarity: [[0.54277766]]
# Linear_similarity: [[0.6652771]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Explore_Statistics_with_R
# Pairwise_similarity: [[0.40067306]]
# Linear_similarity: [[0.5506245]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Microsoft_SharePoint_2016-_Productivity_Solutions
# Pairwise_similarity: [[0.30938938]]
# Linear_similarity: [[0.41673428]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Atomic_and_Optical_Physics-_Light_Forces_and_Laser_Cooling
# Pairwise_similarity: [[0.4687022]]
# Linear_similarity: [[0.5551308]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Mathematical_Modelling_Basics
# Pairwise_similarity: [[0.47434944]]
# Linear_similarity: [[0.64583606]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/How_Media_Got_Social
# Pairwise_similarity: [[0.3448865]]
# Linear_similarity: [[0.47066236]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Multilevel_Converters_for_Medium-High-Power_Applications
# Pairwise_similarity: [[0.4193757]]
# Linear_similarity: [[0.48859018]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Entrepreneurship_for_Global_Challenges_in_EmergingMarkets
# Pairwise_similarity: [[0.4247204]]
# Linear_similarity: [[0.558768]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Global_Health__The_Lessons_of_Ebola
# Pairwise_similarity: [[0.45855936]]
# Linear_similarity: [[0.55797625]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/American_Capitalism-_A_History
# Pairwise_similarity: [[0.36030486]]
# Linear_similarity: [[0.5061379]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Topology_in_Condensed_Matter-_Tying_Quantum_Knots
# Pairwise_similarity: [[0.40739968]]
# Linear_similarity: [[0.48755264]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Software_Testing_Fundamentals
# Pairwise_similarity: [[0.4225837]]
# Linear_similarity: [[0.4804131]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/International_Business_Environment_and_Global_Strategy
# Pairwise_similarity: [[0.44542217]]
# Linear_similarity: [[0.66651314]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Project_Management_of_Engineering_Projects-_Preparing_for_Success
# Pairwise_similarity: [[0.5593156]]
# Linear_similarity: [[0.65070546]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Sex_Science_and_Society
# Pairwise_similarity: [[0.37743607]]
# Linear_similarity: [[0.46294594]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/How_Stuff_Moves_Part_3-_Wave_Motion
# Pairwise_similarity: [[0.41142035]]
# Linear_similarity: [[0.5882835]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Web_Security_Fundamentals
# Pairwise_similarity: [[0.5912024]]
# Linear_similarity: [[0.74470866]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Formal_Software_Verification
# Pairwise_similarity: [[0.44989038]]
# Linear_similarity: [[0.5687367]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Human_Spaceflight_-_An_introduction
# Pairwise_similarity: [[0.43365374]]
# Linear_similarity: [[0.52591145]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/ChinaX_Part_8-_Creating_Modern_China-_The_Birth_of_a_Nation
# Pairwise_similarity: [[0.4264051]]
# Linear_similarity: [[0.50257796]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Fundamentals_of_Nanoelectronics-_Basic_Concepts
# Pairwise_similarity: [[0.60069203]]
# Linear_similarity: [[0.7461446]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/The_Conscious_Mind_-_A_Philosophical_Road_Trip
# Pairwise_similarity: [[0.4240895]]
# Linear_similarity: [[0.5221601]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/A_System_View_of_Communications-_From_Signals_to_Packets_Part_1
# Pairwise_similarity: [[0.4611284]]
# Linear_similarity: [[0.5725937]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/States_and_Markets_in_a_Global_Economy
# Pairwise_similarity: [[0.33327565]]
# Linear_similarity: [[0.4126049]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Autonomous_Navigation_for_Flying_Robots
# Pairwise_similarity: [[0.49957883]]
# Linear_similarity: [[0.6269425]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/AP_Computer_Science_A-_Java_Programming
# Pairwise_similarity: [[0.47601205]]
# Linear_similarity: [[0.6389125]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Optimization_Methods_in_Business_Analytics
# Pairwise_similarity: [[0.4031705]]
# Linear_similarity: [[0.5237811]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/US_Voting_Access_and_Fraud
# Pairwise_similarity: [[0.43691552]]
# Linear_similarity: [[0.68754214]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Strategic_Management-_From_Intuition_to_Insight
# Pairwise_similarity: [[0.35269287]]
# Linear_similarity: [[0.44956625]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Digital_Transformation_Strategy
# Pairwise_similarity: [[0.44599143]]
# Linear_similarity: [[0.5776078]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Mathematical_Modeling_in_the_Life_Sciences_
# Pairwise_similarity: [[0.48907006]]
# Linear_similarity: [[0.6428295]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Practical_Learning_Analytics
# Pairwise_similarity: [[0.4874657]]
# Linear_similarity: [[0.6828778]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Effective_Field_Theory
# Pairwise_similarity: [[0.37838253]]
# Linear_similarity: [[0.5160092]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Embedded_Systems_-_Shape_The_World-_Microcontroller_Input-output
# Pairwise_similarity: [[0.42347378]]
# Linear_similarity: [[0.530309]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Nuclear_Reactor_Physics_Basics
# Pairwise_similarity: [[0.49287838]]
# Linear_similarity: [[0.7376696]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/English_for_Doing_Business_in_Asia_-_Speaking
# Pairwise_similarity: [[0.41385862]]
# Linear_similarity: [[0.4815242]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Applied_Machine_Learning
# Pairwise_similarity: [[0.27926025]]
# Linear_similarity: [[0.41846523]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Mechanics-_Momentum_and_Energy
# Pairwise_similarity: [[0.4041219]]
# Linear_similarity: [[0.5367621]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Discrete_Time_Signals_and_Systems_Part_2-_Frequency_Domain
# Pairwise_similarity: [[0.42145512]]
# Linear_similarity: [[0.5904765]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Introduction_to_Human_Evolution
# Pairwise_similarity: [[0.48095015]]
# Linear_similarity: [[0.56427276]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Evaluating_Designs_with_Users
# Pairwise_similarity: [[0.38718376]]
# Linear_similarity: [[0.550151]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Microsoft_SharePoint_2016-_Workload_Optimization
# Pairwise_similarity: [[0.3547286]]
# Linear_similarity: [[0.4793863]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Windows_Server_2016-_Azure_for_On-Premises_Administrators
# Pairwise_similarity: [[0.36352727]]
# Linear_similarity: [[0.5101702]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Cloud_Computing_Infrastructure
# Pairwise_similarity: [[0.45219362]]
# Linear_similarity: [[0.60877645]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Chinese_Thought-_Ancient_Wisdom_Meets_Modern_Science_-_Part_1
# Pairwise_similarity: [[0.36925593]]
# Linear_similarity: [[0.52522796]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Practical_Improvement_Science_in_Health_Care-_A_Roadmap_for_Getting_Results_V2
# Pairwise_similarity: [[0.46600047]]
# Linear_similarity: [[0.5797442]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Introduction_to_Social_Research_Methods
# Pairwise_similarity: [[0.395522]]
# Linear_similarity: [[0.4885345]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Master_Control_in_Supply_Chain_Management_and_Logistics
# Pairwise_similarity: [[0.3368016]]
# Linear_similarity: [[0.5068814]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Advancing_Learning_Through_Evidence-Based_STEM_Teaching
# Pairwise_similarity: [[0.45095226]]
# Linear_similarity: [[0.530124]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/I_Heart_Stats-_Learning_to_Love_Statistics
# Pairwise_similarity: [[0.45639616]]
# Linear_similarity: [[0.56357056]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Cellular_Solids_1-_Structures_Properties_and_Engineering_Applications
# Pairwise_similarity: [[0.39660132]]
# Linear_similarity: [[0.47039896]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Introduction_to_Web_Cartography-_Part_1
# Pairwise_similarity: [[0.36036327]]
# Linear_similarity: [[0.46394855]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/How_Stuff_Moves_Part_1-_Linear_Motion
# Pairwise_similarity: [[0.5382599]]
# Linear_similarity: [[0.6793966]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Deciphering_Secrets-_Unlocking_the_Manuscripts_of_Medieval_Burgos_Spain
# Pairwise_similarity: [[0.47841617]]
# Linear_similarity: [[0.61001176]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/The_Art_of_Poetry
# Pairwise_similarity: [[0.48746744]]
# Linear_similarity: [[0.6510631]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Electric_Cars-Introduction
# Pairwise_similarity: [[0.4431779]]
# Linear_similarity: [[0.54104674]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Book_Sleuthing-_The_Nineteenth_Century
# Pairwise_similarity: [[0.41301176]]
# Linear_similarity: [[0.5168069]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Developing_Intelligent_Apps_and_Bots
# Pairwise_similarity: [[0.40505892]]
# Linear_similarity: [[0.5327834]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Age_of_Globalization
# Pairwise_similarity: [[0.53289783]]
# Linear_similarity: [[0.6160007]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Electric_and_Conventional_Vehicles
# Pairwise_similarity: [[0.5376231]]
# Linear_similarity: [[0.69652927]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Product_Management_with_Lean_Agile_and_System_Design_Thinking
# Pairwise_similarity: [[0.4468376]]
# Linear_similarity: [[0.56476724]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Making_Science_and_Engineering_Pictures-_A_Practical_Guide_to_Presenting_Your_Work
# Pairwise_similarity: [[0.55217123]]
# Linear_similarity: [[0.6830956]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Flood_Risk_Management
# Pairwise_similarity: [[0.41355023]]
# Linear_similarity: [[0.5161644]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Communication_Acoustics
# Pairwise_similarity: [[0.37468082]]
# Linear_similarity: [[0.74936163]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Microsoft_SharePoint_2016-_Authentication_and_Security
# Pairwise_similarity: [[0.39248788]]
# Linear_similarity: [[0.51712734]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Graphene_Science_and_Technology
# Pairwise_similarity: [[0.5221158]]
# Linear_similarity: [[0.6595496]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Quantum_Cryptography
# Pairwise_similarity: [[0.5791911]]
# Linear_similarity: [[0.6973093]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Agile_Development_Using_Ruby_on_Rails_-_The_Basics
# Pairwise_similarity: [[0.44510528]]
# Linear_similarity: [[0.5808051]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/A_History_of_Violence-_From_the_Middle_Ages_to_Modern_Times
# Pairwise_similarity: [[0.44594872]]
# Linear_similarity: [[0.60236317]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Implementation_and_Evaluation_of_Educational_Technology
# Pairwise_similarity: [[0.56011313]]
# Linear_similarity: [[0.73629177]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Computer_Systems_Design_for_Energy_Efficiency
# Pairwise_similarity: [[0.37223732]]
# Linear_similarity: [[0.53601736]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Embedded_Systems_-_Shape_The_World-_Multi-threaded_Interfacing
# Pairwise_similarity: [[0.40018332]]
# Linear_similarity: [[0.6000032]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Fun_with_Prime_Numbers-_The_Mysterious_World_of_Mathematics
# Pairwise_similarity: [[0.4651757]]
# Linear_similarity: [[0.6003094]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Data_Science_Readiness_Assessment
# Pairwise_similarity: [[0.3513633]]
# Linear_similarity: [[0.54223484]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Planning_and_Preparing_SharePoint_Hybrid
# Pairwise_similarity: [[0.47626507]]
# Linear_similarity: [[0.62390316]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Managing_SQL_Database_Transactions_and_Concurrency
# Pairwise_similarity: [[0.31299824]]
# Linear_similarity: [[0.38786742]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Risk_Management_for_Projects
# Pairwise_similarity: [[0.5360957]]
# Linear_similarity: [[0.6965315]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Introduction_to_Programming_Using_Python
# Pairwise_similarity: [[0.3261509]]
# Linear_similarity: [[0.35041705]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Accounting_for_Decision-Making
# Pairwise_similarity: [[0.33474746]]
# Linear_similarity: [[0.4964575]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/The_Science_and_Practice_of_Yoga
# Pairwise_similarity: [[0.62911415]]
# Linear_similarity: [[0.7490267]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Critical_Thinking__Problem_Solving
# Pairwise_similarity: [[0.38333148]]
# Linear_similarity: [[0.52618897]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Introduction_to_Engineering_Mathematics_with_Applications
# Pairwise_similarity: [[0.37827262]]
# Linear_similarity: [[0.44633424]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Omnichannel_Strategy_and_Management
# Pairwise_similarity: [[0.5344723]]
# Linear_similarity: [[0.73162]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Operations_Management
# Pairwise_similarity: [[0.38066843]]
# Linear_similarity: [[0.5204868]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Cyber_Security_Economics
# Pairwise_similarity: [[0.47797495]]
# Linear_similarity: [[0.61967325]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Personal_Finance_1-_Investing_in_yourself_and_making_the_most_of_your_investment
# Pairwise_similarity: [[0.50979227]]
# Linear_similarity: [[0.66656613]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/The_Computing_Technology_Inside_Your_Smartphone
# Pairwise_similarity: [[0.43683022]]
# Linear_similarity: [[0.5303006]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Journalism_for_Social_Change
# Pairwise_similarity: [[0.4822164]]
# Linear_similarity: [[0.6108233]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Becoming_a_Resilient_Person-_The_Science_of_Stress_Management_and_Promoting_Wellbeing
# Pairwise_similarity: [[0.5729397]]
# Linear_similarity: [[0.6527472]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Introduction_to_Animal_Ethics
# Pairwise_similarity: [[0.42177954]]
# Linear_similarity: [[0.58629805]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Underactuated_Robotics
# Pairwise_similarity: [[0.39453566]]
# Linear_similarity: [[0.44940645]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/u.lab-_Leading_From_the_Emerging_Future
# Pairwise_similarity: [[0.4631704]]
# Linear_similarity: [[0.47400415]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Causal_Diagrams-_Draw_Your_Assumptions_Before_Your_Conclusions
# Pairwise_similarity: [[0.41409823]]
# Linear_similarity: [[0.50470114]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Force_and_Motion-_Pedagogical_Content_Knowledge_for_Teaching_Physics
# Pairwise_similarity: [[0.3625348]]
# Linear_similarity: [[0.4766194]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Biological_Engineering-_Cellular_Design_Principles
# Pairwise_similarity: [[0.3634321]]
# Linear_similarity: [[0.5065387]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Human_Rights_Theory_and_Philosophy_T2_2017
# Pairwise_similarity: [[0.47104946]]
# Linear_similarity: [[0.5441678]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Math_in_Sports
# Pairwise_similarity: [[0.3346858]]
# Linear_similarity: [[0.4968422]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Data_Analysis_Essentials_for_MBA_Success
# Pairwise_similarity: [[0.12351394]]
# Linear_similarity: [[0.24702789]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Effective_Thinking_Through_Mathematics
# Pairwise_similarity: [[0.4624206]]
# Linear_similarity: [[0.53533506]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Trends_in_e-Psychology
# Pairwise_similarity: [[0.3616018]]
# Linear_similarity: [[0.49197558]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/The_Engineering_of_Structures_Around_Us
# Pairwise_similarity: [[0.44912887]]
# Linear_similarity: [[0.59208804]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/European_Paintings-_From_Leonardo_to_Rembrandt_to_Goya
# Pairwise_similarity: [[0.58904755]]
# Linear_similarity: [[0.7531684]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Preparing_for_the_AP_Computer_Science_A_Exam_Part_2
# Pairwise_similarity: [[0.31272078]]
# Linear_similarity: [[0.48489136]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Preparing_for_the_AP_Computer_Science_A_Exam_-_Part_1
# Pairwise_similarity: [[0.3734485]]
# Linear_similarity: [[0.6167431]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/SharePoint_Enterprise_Content_Management
# Pairwise_similarity: [[0.4370915]]
# Linear_similarity: [[0.56781423]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Enabling_Office_365_Clients
# Pairwise_similarity: [[0.3421384]]
# Linear_similarity: [[0.50140315]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Big_Data_Strategies_to_Transform_Your_Business
# Pairwise_similarity: [[0.44739485]]
# Linear_similarity: [[0.534013]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Nonlinear_Differential_Equations-_Order_and_Chaos
# Pairwise_similarity: [[0.449549]]
# Linear_similarity: [[0.5897602]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Introduction_to_Functional_Programming
# Pairwise_similarity: [[0.48489058]]
# Linear_similarity: [[0.5567133]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Introduction_to_Bioelectricity
# Pairwise_similarity: [[0.46755195]]
# Linear_similarity: [[0.5712791]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Linear_Differential_Equations
# Pairwise_similarity: [[0.4893949]]
# Linear_similarity: [[0.5541504]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Technology_Evaluation_for_Global_Development
# Pairwise_similarity: [[0.2898946]]
# Linear_similarity: [[0.39553937]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/The_Science_and_Politics_of_the_GMO
# Pairwise_similarity: [[0.50095075]]
# Linear_similarity: [[0.6113268]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Artful_Medicine
# Pairwise_similarity: [[0.37414536]]
# Linear_similarity: [[0.59304976]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Global_Sociology
# Pairwise_similarity: [[0.4041397]]
# Linear_similarity: [[0.4968717]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Designing_for_Experimentation_to_Enhance_Digital_Business_Innovation
# Pairwise_similarity: [[0.4387826]]
# Linear_similarity: [[0.6012581]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/AP_English_Literature__Composition__Part_1-_Stories
# Pairwise_similarity: [[0.4770247]]
# Linear_similarity: [[0.6261172]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/The_Quantum_World
# Pairwise_similarity: [[0.5359212]]
# Linear_similarity: [[0.64689916]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Shakespeare_On_the_Page_and_in_Performance-_Young_Love
# Pairwise_similarity: [[0.6102393]]
# Linear_similarity: [[0.80190897]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Computing-_Art_Magic_Science
# Pairwise_similarity: [[0.4357744]]
# Linear_similarity: [[0.58803004]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Marketing_Management
# Pairwise_similarity: [[0.38996994]]
# Linear_similarity: [[0.5391046]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Portfolio_Management_Governance__the_PMO
# Pairwise_similarity: [[0.5600114]]
# Linear_similarity: [[0.7675805]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Was_Alexander_Great
# Pairwise_similarity: [[0.579403]]
# Linear_similarity: [[0.6528348]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Paradigms_of_Computer_Programming_-_Fundamentals
# Pairwise_similarity: [[0.44455925]]
# Linear_similarity: [[0.5239214]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Lessons_from_Ebola-_Preventing_the_Next_Pandemic
# Pairwise_similarity: [[0.5643715]]
# Linear_similarity: [[0.73922646]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Library_Advocacy_Unshushed
# Pairwise_similarity: [[0.4891371]]
# Linear_similarity: [[0.59215385]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/New_Trends_in_Trade_Agreements_in_Latin_America__the_Caribbean
# Pairwise_similarity: [[0.4256332]]
# Linear_similarity: [[0.5640997]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Neuronal_Dynamics
# Pairwise_similarity: [[0.52792686]]
# Linear_similarity: [[0.7022696]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Structural_Materials-_Selection_and_Economics
# Pairwise_similarity: [[0.2714447]]
# Linear_similarity: [[0.444659]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Quantum_Mechanics-_1D_Scattering_and_Central_Potentials
# Pairwise_similarity: [[0.3942517]]
# Linear_similarity: [[0.60288566]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Urban_Water_-_Innovations_for_Environmental_Sustainability
# Pairwise_similarity: [[0.46792993]]
# Linear_similarity: [[0.55812925]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Culture_of_Services-_New_Perspective_on_Customer_Relations
# Pairwise_similarity: [[0.5028246]]
# Linear_similarity: [[0.6369859]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/AP_Computer_Science_A-_Java_Programming_Classes_and_Objects
# Pairwise_similarity: [[0.21637498]]
# Linear_similarity: [[0.43274996]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Paradigms_of_Computer_Programming_-_Abstraction_and_Concurrency
# Pairwise_similarity: [[0.37968776]]
# Linear_similarity: [[0.5480514]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Reliable_Distributed_Algorithms_-_Part_2
# Pairwise_similarity: [[0.3817313]]
# Linear_similarity: [[0.46440458]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Accessible_Gamification
# Pairwise_similarity: [[0.569768]]
# Linear_similarity: [[0.75820464]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/The_Iterative_Innovation_Process
# Pairwise_similarity: [[0.36925873]]
# Linear_similarity: [[0.52328134]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Human_Rights_Activism_Advocacy_and_Change_T2_2017
# Pairwise_similarity: [[0.43308917]]
# Linear_similarity: [[0.51844364]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Computer_System_Design-_Advanced_Concepts_of_Modern_Microprocessors
# Pairwise_similarity: [[0.34515116]]
# Linear_similarity: [[0.486961]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Quantum_Mechanics-_Wavefunctions_operators_and_expectation_values
# Pairwise_similarity: [[0.3973407]]
# Linear_similarity: [[0.576503]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Digital_Strategy_and_Action
# Pairwise_similarity: [[0.41966546]]
# Linear_similarity: [[0.5668876]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/DO_Your_Venture_-_Entrepreneurship_for_Everyone
# Pairwise_similarity: [[0.4558932]]
# Linear_similarity: [[0.54482687]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Statistics_and_Probability_in_Data_Science_using_Python
# Pairwise_similarity: [[0.42229533]]
# Linear_similarity: [[0.58309907]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Developing_Windows_10_Universal_Apps__Part_2
# Pairwise_similarity: [[0.39211106]]
# Linear_similarity: [[0.5485779]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/An_Introduction_to_Evidence-Based_Undergraduate_STEM_Teaching
# Pairwise_similarity: [[0.5121461]]
# Linear_similarity: [[0.6035392]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/The_EU_and_Human_Rights
# Pairwise_similarity: [[0.4503867]]
# Linear_similarity: [[0.61597687]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/The_Medieval_Icelandic_Sagas
# Pairwise_similarity: [[0.5640745]]
# Linear_similarity: [[0.68050045]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Leadership_in_a_New_Era-_A_Course_at_Tsinghua_SEM_by_McKinsey_
# Pairwise_similarity: [[0.7031696]]
# Linear_similarity: [[0.88156986]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Quantum_Information_Science_I_Part_1
# Pairwise_similarity: [[0.1991854]]
# Linear_similarity: [[0.3226471]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/U.S._Government_-_Foundations_Democracy__Politics
# Pairwise_similarity: [[0.47457623]]
# Linear_similarity: [[0.6528691]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Business_Accounting_Basics
# Pairwise_similarity: [[0.52121186]]
# Linear_similarity: [[0.6699391]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Healthcare_in_India-_Strategic_Perspectives
# Pairwise_similarity: [[0.46615028]]
# Linear_similarity: [[0.6326965]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Modeling_Climate_Change
# Pairwise_similarity: [[0.47756767]]
# Linear_similarity: [[0.61523193]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Shakespeare_Matters
# Pairwise_similarity: [[0.5836223]]
# Linear_similarity: [[0.7403022]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Introduction_to_Data_Structures
# Pairwise_similarity: [[0.5194065]]
# Linear_similarity: [[0.6247615]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Incarcerations_Witnesses-_American_Prison_Writing
# Pairwise_similarity: [[0.4395192]]
# Linear_similarity: [[0.6074678]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Anthropology_of_Current_World_Issues
# Pairwise_similarity: [[0.12708251]]
# Linear_similarity: [[0.25416502]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Applications_of_Linear_Algebra_Part_1
# Pairwise_similarity: [[0.36036557]]
# Linear_similarity: [[0.46771663]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Scrolls_in_the_Age_of_the_Book
# Pairwise_similarity: [[0.51137644]]
# Linear_similarity: [[0.6373343]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Calculus_1B-_Integration
# Pairwise_similarity: [[0.4398525]]
# Linear_similarity: [[0.58139676]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Cloud_Computing_Security
# Pairwise_similarity: [[0.40054584]]
# Linear_similarity: [[0.50122696]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Introduction_to_Control_System_Design__A_First_Look
# Pairwise_similarity: [[0.40589982]]
# Linear_similarity: [[0.58310336]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Introduction_to_Sociology
# Pairwise_similarity: [[0.46409744]]
# Linear_similarity: [[0.55798876]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Statistical_Analysis_in_Bioinformatics
# Pairwise_similarity: [[0.4713633]]
# Linear_similarity: [[0.5668046]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Queuing_Theory-_from_Markov_Chains_to_Multi-Server_Systems
# Pairwise_similarity: [[0.4127359]]
# Linear_similarity: [[0.5471749]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Mechanics-_Kinematics_and_Dynamics
# Pairwise_similarity: [[0.3486839]]
# Linear_similarity: [[0.43841854]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Software_Construction_in_Java
# Pairwise_similarity: [[0.3902222]]
# Linear_similarity: [[0.37257805]]
# UNUSUAL CASE
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Differential_Equations-_2x2_Systems
# Pairwise_similarity: [[0.32995376]]
# Linear_similarity: [[0.46871233]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Industrial_Biotechnology
# Pairwise_similarity: [[0.5400781]]
# Linear_similarity: [[0.68046814]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Managing_Marketing_in_the_Hospitality_and_Tourism_Industry
# Pairwise_similarity: [[0.4202038]]
# Linear_similarity: [[0.4902452]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Introduction_to_Data_Science
# Pairwise_similarity: [[0.40614897]]
# Linear_similarity: [[0.5375613]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Mobile_Application_Experiences_Part_2-_Mobile_App_Design
# Pairwise_similarity: [[0.39471027]]
# Linear_similarity: [[0.54161704]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/The_Ethics_of_Memory
# Pairwise_similarity: [[0.3668934]]
# Linear_similarity: [[0.57730573]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Mobile_Application_Experiences
# Pairwise_similarity: [[0.30842987]]
# Linear_similarity: [[0.3332317]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Strategic_Applications_of_IT_Project__Program_Management
# Pairwise_similarity: [[0.46191108]]
# Linear_similarity: [[0.58682]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Introduction_to_Global_Hospitality_Management
# Pairwise_similarity: [[0.39500308]]
# Linear_similarity: [[0.53144664]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Global_Marketing_Strategy
# Pairwise_similarity: [[0.35609242]]
# Linear_similarity: [[0.48946062]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Nature_in_Code-_Biology_in_JavaScript
# Pairwise_similarity: [[0.35227373]]
# Linear_similarity: [[0.5673915]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Global_Warming_Science
# Pairwise_similarity: [[0.3507409]]
# Linear_similarity: [[0.4977252]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Capstone_Project
# Pairwise_similarity: [[0.4108644]]
# Linear_similarity: [[0.5320614]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Digital_Dividends-_Strengthening_the_Analog_Foundation_of_the_Digital_Revolution
# Pairwise_similarity: [[0.4140462]]
# Linear_similarity: [[0.48964542]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Shakespeare_On_the_Page_and_in_Performance-_Tragic_Love
# Pairwise_similarity: [[0.6371935]]
# Linear_similarity: [[0.7984481]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Jesus_in_Scripture_and_Tradition
# Pairwise_similarity: [[0.42723715]]
# Linear_similarity: [[0.47482458]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Applications_of_Linear_Algebra_Part_2
# Pairwise_similarity: [[0.39052892]]
# Linear_similarity: [[0.44908524]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Vacuum_Systems_and_Technology
# Pairwise_similarity: [[0.51562285]]
# Linear_similarity: [[0.6986861]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Evaluating_Social_Programs
# Pairwise_similarity: [[0.48283666]]
# Linear_similarity: [[0.59757376]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Cognitive_Neuroscience_Robotics__Part_A
# Pairwise_similarity: [[0.23821582]]
# Linear_similarity: [[0.39580736]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Thermodynamics
# Pairwise_similarity: [[0.4422792]]
# Linear_similarity: [[0.556763]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Leading_in_the_Digital_Age
# Pairwise_similarity: [[0.4474748]]
# Linear_similarity: [[0.5789814]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Configuring_SharePoint_Hybrid
# Pairwise_similarity: [[0.4091309]]
# Linear_similarity: [[0.5025297]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Globalizations_Winners_and_Losers
# Pairwise_similarity: [[0.43041262]]
# Linear_similarity: [[0.5368241]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/The_History_of_the_Book_in_17th_and_18th_Century_Europe
# Pairwise_similarity: [[0.40833694]]
# Linear_similarity: [[0.5912535]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Signals_and_Systems_Part_1
# Pairwise_similarity: [[0.49498194]]
# Linear_similarity: [[0.60551244]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Robot_Mechanics_and_Control_Part_I
# Pairwise_similarity: [[0.37196568]]
# Linear_similarity: [[0.529012]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Leadership_and_Management_for_PM_Practitioners_in_IT
# Pairwise_similarity: [[0.5357923]]
# Linear_similarity: [[0.7511633]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Principles_of_Economics_with_Calculus
# Pairwise_similarity: [[0.55435836]]
# Linear_similarity: [[0.6912678]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs/Financial_Decision_Making
# Pairwise_similarity: [[0.43991387]]
# Linear_similarity: [[0.5542982]]
# UNUSUAL CASE COUNT 3

# %% [markdown]
# In figure bellow you can see, that mean value of lc-score distribution is higher than the mean of pc-score distribution.

# %%
import numpy as np
from matplotlib.pyplot import *
import matplotlib.pyplot as plt

font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : 18}

matplotlib.rc('font', **font)

mean_pairwise = [np.mean(pairwise_sim_points)]*len(pairwise_sim_points)
mean_linear = [np.mean(linear_sim_points)]*len(linear_sim_points)

plt.figure(figsize=(20,10))
plt.plot(np.array(range(len(pairwise_sim_points))), np.array(pairwise_sim_points).reshape(-1,1), 'o-')
plt.plot(np.array(range(len(linear_sim_points))), np.array(linear_sim_points).reshape(-1,1), 'o-')

# Plot the average line
plt.plot(np.array(range(len(pairwise_sim_points))),mean_pairwise, label='Mean', linestyle='--', linewidth=5.0)
plt.plot(np.array(range(len(linear_sim_points))),mean_linear, label='Mean', linestyle='--', linewidth=5.0)

plt.xlabel('courses')
plt.ylabel('similarity')

plt.legend(['pairwise_sim', 'linear_sim', 'mean_pairwise', 'mean_linear'], loc='lower left')
plt.show()
# Out:
# /home/zarina/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1316: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# #  Section similarities of TitechX courses

# %%
from textstat.textstat import textstat

# compute readability for course sections
def compute_readability(section_to_content):
    
    section_readabilities = []
    keys = sorted(section_to_content.keys())
    
    for section in range(0,len(keys)):
        list_txt = section_to_content[keys[section]]
        txt = ''.join(str(e) for e in list_txt)
        readability = textstat.flesch_reading_ease(txt)
        section_readabilities.append(readability)
    
    return section_readabilities

# %%
import matplotlib.pyplot as plt
import networkx as nx
import pygraphviz
from networkx.drawing.nx_agraph import graphviz_layout
#from sklearn.preprocessing import Normalizer
from sklearn.preprocessing import MinMaxScaler
import numpy as np

rootDir='/home/zarina/Documents/OEDO/web-crawler/HTMLs_titech/'
selected_components=['all_textcomp.json', 'all_videocomp.json']
course_dir = [tmp for tmp in os.listdir(rootDir)]
readabilities=[]
case_count=0

pairwise_sim_points = []
linear_sim_points = []
course_names = []

for course in course_dir:
    
    course_names.append(course)
    course_path = rootDir + course #/rootDir/course_name
    print (course_path)
    
    section_to_content =  defaultdict(list)
    section_to_vector =  defaultdict(list)
    
    section_to_content = get_course_sections(course_path)
    
    section_to_vector =  defaultdict(list)
    for key, value in section_to_content.items():
        #combine list
        section_txt=''.join(str(e) for e in value)
        #clean text '110' - alphabetic, numeric
        clean_txt=text_preprocess(section_txt, '110')
        #inferred_embedding
        inferred_embedding = model0.infer_vector(clean_txt)
        #store embedding in map
        section_to_vector[key]=inferred_embedding
    
    pairwise_section_sim = compute_parwise_similarity(section_to_vector)
    pairwise_sim_points.append(pairwise_section_sim)
    
    G=nx.Graph()
    node_sizes=[]
        
    section_readabilities = compute_readability(section_to_content)
    print ("Sections readabilities", section_readabilities)
    node_sizes = section_readabilities
    
    section_names = list(section_to_content.keys())
    for i, name in enumerate(section_names):
        G.add_node(name ,pos=(50, 100-i*10))

    #normailzing readability to draw node sizes
    scaler = MinMaxScaler(feature_range=(200, 3000))
    scaler = scaler.fit( np.array(node_sizes).reshape(-1, 1))
    normalized = scaler.transform(np.array(node_sizes).reshape(-1, 1))
    
    plt.figure(figsize=(10,10))
    pos=nx.get_node_attributes(G,'pos')
    nx.draw_networkx_nodes(G, pos,  node_size=normalized, node_color='b', alpha=0.7)
    
    #defining edge weights as ls-score
    _, linear_similarities = compute_linear_similarity(section_to_vector)
   
    for ind in range(len(section_names) - 1):#iterate thru sections
        G.add_edge(section_names[ind], section_names[ind+1], weight=linear_similarities[ind])
    
    elarge = [(u, v) for (u, v, d) in G.edges(data=True) if d['weight'] > 0.5]
    esmall = [(u, v) for (u, v, d) in G.edges(data=True) if d['weight'] <= 0.5]
     
    nx.draw_networkx_edges(G, pos, edgelist=elarge, width=10, alpha=0.7, edge_color='g',length=10000)
    nx.draw_networkx_edges(G, pos, edgelist=esmall, width=10, alpha=0.7, edge_color='r', length=10000)
    
    plt.show()
# Out:
# /home/zarina/Documents/OEDO/web-crawler/HTMLs_titech/Modern_Japanese_Architect-Meiji_Restoration_to_Today
# Pairwise_similarity: [[0.37544176]]
# Sections readabilities [60.04, 42.45, 34.8, 33.17, 33.07, 31.45, 48.43, 29.86]
# Linear_similarity: [[0.4984351]]
# /home/zarina/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1316: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# /home/zarina/Documents/OEDO/web-crawler/HTMLs_titech/Introduction_to_Deep_Earth_Science
# Pairwise_similarity: [[0.4159412]]
# Sections readabilities [64.71, 65.12, 53.81, 54.42, 45.56, 53.41, 62.27, 65.01]
# Linear_similarity: [[0.5237802]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs_titech/Introduction_to_Electrical_and_Electronic_Engineering_-__Self-Paced
# Pairwise_similarity: [[0.31473765]]
# Sections readabilities [47.89, 65.32, 49.21, 46.81, 58.28, 58.82]
# Linear_similarity: [[0.4682917]]
# /home/zarina/Documents/OEDO/web-crawler/HTMLs_titech/Autophagy-_Research_Behind_the_2016_Nobel_Prize_in_Physiology_or_Medicine
# Pairwise_similarity: [[0.42325264]]
# Sections readabilities [52.6, 54.63, 52.39, 51.99]
# Linear_similarity: [[0.55728495]]
